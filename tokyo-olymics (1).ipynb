# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd
# data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/olympic-games-2021-medals/Tokyo 2021 dataset.csv

# %% [markdown]
#  * ****To visualise the raw data in graphical,tabular forms, we have imported various python Libraries such as numpy,pandas, matplotlib,seaborn etc....****

# %%
data=pd.read_csv("../input/olympic-games-2021-medals/Tokyo 2021 dataset.csv")

# %% [markdown]
# * **The pandas function read_csv() reads in values, where the delimiter is a comma character. You can export a file into a csv file in any modern office suite including Google Sheets. Use the following csv data as an example. If you want to export data from a DataFrame or pandas.**
# * **By doing so the entire data in the data set is in our hands we would later use this data as we desire**

# %%
data
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# ...

# %% [markdown]
# * **Since the data set is csv file,we have got entire data in tabular form**

# %%
data.head()
# Out:
#    Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0     1    United States of America          39            41            33
# 1     2  People's Republic of China          38            32            18
# 2     3                       Japan          27            14            17
# 3     4               Great Britain          22            21            22
# 4     5                         ROC          20            28            23
#
#    Total  Rank by Total NOCCode
# 0    113              1     USA
# 1     88              2     CHN
# 2     58              5     JPN
# 3     65              4     GBR
# 4     71              3     ROC

# %% [markdown]
# * **The head() function is used to get the first n (5 by default) rows. This function returns the first n(5 by default) rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it**
# * **So that we came to know  that our data is perfect!**

# %%
data.tail()
# Out:
#     Rank              Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 88    86                 Ghana           0             0             1      1
# 89    86               Grenada           0             0             1      1
# 90    86                Kuwait           0             0             1      1
# 91    86   Republic of Moldova           0             0             1      1
# 92    86  Syrian Arab Republic           0             0             1      1
#
#     Rank by Total NOCCode
# 88             77     GHA
# 89             77     GRN
# 90             77     KUW
# 91             77     MDA
# 92             77     SYR

# %% [markdown]
# * **Return the last n(5 by default) rows. This function returns last n(5 by default) rows from the object based on position. It is useful for quickly verifying data.**
# * **Just re-verifying!!**

# %%
data.columns
# Out:
# Index(['Rank', 'Team/NOC', 'Gold Medal', 'Silver Medal', 'Bronze Medal',
#        'Total', 'Rank by Total', 'NOCCode'],
#       dtype='object')

# %% [markdown]
# * **columns attribute return the column labels of the given Dataframe.**
# * **We have got all the coloumns(Headings/Parameters) in our Data**

# %%
data.shape
# Out:
# (93, 8)

# %% [markdown]
# * **The shape attribute of pandas stores the number of rows and columns as a tuple(number of rows, number of columns)**
# * **We came to know that our data has 93 rows and 8 columns**

# %%
data.dtypes.value_counts()
# Out:
# int64     6
# object    2
# dtype: int64

# %% [markdown]
# * **We have used the value_counts() function to get a Series containing counts of unique values**
# * **Now,We know the number of unique values in our Data**

# %%
data.isnull()
# Out:
#      Rank  Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0   False     False       False         False         False  False
# 1   False     False       False         False         False  False
# 2   False     False       False         False         False  False
# 3   False     False       False         False         False  False
# 4   False     False       False         False         False  False
# ..    ...       ...         ...           ...           ...    ...
# 88  False     False       False         False         False  False
# 89  False     False       False         False         False  False
# 90  False     False       False         False         False  False
# 91  False     False       False         False         False  False
# 92  False     False       False         False         False  False
#
#     Rank by Total  NOCCode
# 0           False    False
# 1           False    False
# 2           False    False
# 3           False    False
# ...

# %% [markdown]
# * **This Function Returns a Boolean value that indicates whether an expression contains no valid data (Null).**

# %%
data.describe()
# Out:
#             Rank  Gold Medal  Silver Medal  Bronze Medal       Total  \
# count  93.000000   93.000000     93.000000     93.000000   93.000000
# mean   46.333333    3.655914      3.634409      4.322581   11.612903
# std    26.219116    7.022471      6.626339      6.210372   19.091332
# min     1.000000    0.000000      0.000000      0.000000    1.000000
# 25%    24.000000    0.000000      0.000000      1.000000    2.000000
# 50%    46.000000    1.000000      1.000000      2.000000    4.000000
# 75%    70.000000    3.000000      4.000000      5.000000   11.000000
# max    86.000000   39.000000     41.000000     33.000000  113.000000
#
#        Rank by Total
# count      93.000000
# mean       43.494624
# std        24.171769
# min         1.000000
# 25%        23.000000
# 50%        47.000000
# 75%        66.000000
# max        77.000000

# %% [markdown]
# * **Pandas describe() is used to view some basic statistical details like percentile, mean, std,min,max,count....etc. of a data frame or a series of numeric values**
# * **Now we have the values of various statistical parameters like mean,min,count,max,etc for every coloumn**

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# * **We have divided the data set into three quartiles using boxplot() function.**
# * **This graph represents the minimum, maximum, median, first quartile and third quartile in the data set. It is also useful in comparing the distribution of data across data sets by drawing boxplots for each of them.**

# %%
x= data["Team/NOC"]
y=data["Bronze Medal"]
plt.scatter(x, y)
plt.show()

# %% [markdown]
# * **A Scatter plot is a type of data visualization technique that shows the relationship between two numerical variables.**
# * **Shall we add a scatter() plot into our EDA? SURE!!!**
# * **By Calling the scatter() method on the plot member draws a plot between two variables or two columns of pandas DataFrame.**
# * **Our Scatter plot is between "Team/NOC" and "Bronze Medal"**

# %%
data.max()
# Out:
# Rank                    86
# Team/NOC         Venezuela
# Gold Medal              39
# Silver Medal            41
# Bronze Medal            33
# Total                  113
# Rank by Total           77
# NOCCode                VEN
# dtype: object

# %% [markdown]
# * **max() returns the maximum value in each coloumn**
# * **Hence,we've got the maximum values of each column in our data i.e., eight coloumns**
# * Note: In case of strings,it returns maximum value based on their corresponding ASCII values

# %% [markdown]
# * ****

# %%
data.min()
# Out:
# Rank                     1
# Team/NOC         Argentina
# Gold Medal               0
# Silver Medal             0
# Bronze Medal             0
# Total                    1
# Rank by Total            1
# NOCCode                ARG
# dtype: object

# %% [markdown]
# * **min() returns the maximum value in each coloumn**
# * **Hence,we've got the minimum values of each column in our data i.e., eight coloumns**
# * Note: In case of strings,it returns minimum value based on their corresponding ASCII values

# %%
data.loc[data['Team/NOC'] == "India"]
# Out:
#     Rank Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 47    48    India           1             2             4      7
#
#     Rank by Total NOCCode
# 47             33     IND

# %% [markdown]
# * **The loc property is used to access a group of rows and columns by label(s) or a boolean array.**
# * **We have used this function to know the achievements of our beloved INDIA in Tokyo Olympics 2021**

# %% [markdown]
# * ****

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Rank'}>,
#         <AxesSubplot:title={'center':'Gold Medal'}>],
#        [<AxesSubplot:title={'center':'Silver Medal'}>,
#         <AxesSubplot:title={'center':'Bronze Medal'}>],
#        [<AxesSubplot:title={'center':'Total'}>,
#         <AxesSubplot:title={'center':'Rank by Total'}>]], dtype=object)

# %% [markdown]
# * **The hist() function in pyplot module of matplotlib library is used to plot a histogram. **
# * **Here,we've got histograms between various parameters/coloumns**

# %%
plt.figure(figsize=(40,10))
sns.scatterplot(x=data['NOCCode'], y=data['Total'])
# Out:
# <AxesSubplot:xlabel='NOCCode', ylabel='Total'>

# %% [markdown]
# * **Scatter plots' primary uses are to observe and show relationships between two numeric variables.**
# * **This scatterplot is between 'NOCCode' and 'Total'**

# %%
plt.figure(figsize=(30,50))
# Bar chart showing average score for racing games by platform
sns.barplot(x=data['Rank'], y=data["Team/NOC"])
# Add label for horizontal axis
plt.xlabel("")
# Add label for vertical axis
plt.title("Average Score for Racing Games, by Platform")

# Check your answer
# Out:
# Text(0.5, 1.0, 'Average Score for Racing Games, by Platform')

# %% [markdown]
# * **barplot() method. A barplot is basically used to aggregate the categorical data according to some methods and by default it's the mean.**
# * **This is the bar plot between "Rank" and "Team/NOC"**

# %%
plt.figure(figsize=(50,6))
# Line chart showing the number of visitors to each museum over time
sns.lineplot(x="NOCCode",y="Gold Medal",data=data)
plt.xlabel("country")
plt.title("country")
# Out:
# Text(0.5, 1.0, 'country')

# %% [markdown]
# * **This is the lineplot between "NOCCode" and "Gold Medal"**
# * **figure creates a new figure window using default property values. The resulting figure is the current figure. figure( Name,Value ) modifies properties of the figure using one or more name-value pair arguments.**

# %%
plt.figure(figsize=(50,6))
# Line chart showing the number of visitors to each museum over time
sns.lineplot(x="NOCCode",y="Total",data=data)
plt.xlabel("country")
plt.title("country")
# Out:
# Text(0.5, 1.0, 'country')

# %% [markdown]
# * **This is the lineplot between "NOCCode" and "Total"**
# * **figure creates a new figure window using default property values. The resulting figure is the current figure. figure( Name,Value ) modifies properties of the figure using one or more name-value pair arguments.**
